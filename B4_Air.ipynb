# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("D:/DSBDA/AirQuality_visualization.csv", sep=';')

# %%
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# 0          1268.0  13,6  48,9  0,7578          NaN          NaN
# 1           972.0  13,3  47,7  0,7255          NaN          NaN
# 2          1074.0  11,9  54,0  0,7502          NaN          NaN
# 3          1203.0  11,0  60,0  0,7867          NaN          NaN
# 4          1110.0  11,2  59,6  0,7888          NaN          NaN
# ...           ...   ...   ...     ...          ...          ...
# 9466          NaN   NaN   NaN     NaN          NaN          NaN
# 9467          NaN   NaN   NaN     NaN          NaN          NaN
# 9468          NaN   NaN   NaN     NaN          NaN          NaN
# 9469          NaN   NaN   NaN     NaN          NaN          NaN
# 9470          NaN   NaN   NaN     NaN          NaN          NaN
#
# [9471 rows x 17 columns]

# %%
#Renamre column name

# %%
df = df.rename(columns={'T': 'Temperature'})

# %%
df = df.rename(columns={'RH': 'Relative Humidity'})

# %%
df = df.rename(columns={'AH': 'Absolute Humidity'})

# %%
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3) Temperature Relative Humidity Absolute Humidity  \
# 0          1268.0        13,6              48,9            0,7578
# 1           972.0        13,3              47,7            0,7255
# 2          1074.0        11,9              54,0            0,7502
# 3          1203.0        11,0              60,0            0,7867
# 4          1110.0        11,2              59,6            0,7888
# ...           ...         ...               ...               ...
# 9466          NaN         NaN               NaN               NaN
# 9467          NaN         NaN               NaN               NaN
# 9468          NaN         NaN               NaN               NaN
# 9469          NaN         NaN               NaN               NaN
# 9470          NaN         NaN               NaN               NaN
#
#       Unnamed: 15  Unnamed: 16
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 9466          NaN          NaN
# 9467          NaN          NaN
# 9468          NaN          NaN
# 9469          NaN          NaN
# 9470          NaN          NaN
#
# [9471 rows x 17 columns]

# %%
#deop column

# %%
df = df.drop(['Unnamed: 15', 'Unnamed: 16'],axis=1)

# %%
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3) Temperature Relative Humidity Absolute Humidity
# 0          1268.0        13,6              48,9            0,7578
# 1           972.0        13,3              47,7            0,7255
# 2          1074.0        11,9              54,0            0,7502
# 3          1203.0        11,0              60,0            0,7867
# 4          1110.0        11,2              59,6            0,7888
# ...           ...         ...               ...               ...
# 9466          NaN         NaN               NaN               NaN
# 9467          NaN         NaN               NaN               NaN
# 9468          NaN         NaN               NaN               NaN
# 9469          NaN         NaN               NaN               NaN
# 9470          NaN         NaN               NaN               NaN
#
# [9471 rows x 15 columns]

# %%
df['CO(GT)'] = df['CO(GT)'].str.replace(',', '.').astype(float)

# %%
df['C6H6(GT)'] = df['C6H6(GT)'].str.replace(',', '.').astype(float)

# %%
df['Temperature'] = df['Temperature'].str.replace(',','.').astype(float)

# %%
df['Relative Humidity'] = df['Relative Humidity'].str.replace(',', '.').astype(float)

# %%
df['Absolute Humidity'] = df['Absolute Humidity'].str.replace(',', '.').astype(float)

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9466         NaN       NaN     NaN          NaN       NaN       NaN
# 9467         NaN       NaN     NaN          NaN       NaN       NaN
# 9468         NaN       NaN     NaN          NaN       NaN       NaN
# 9469         NaN       NaN     NaN          NaN       NaN       NaN
# 9470         NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)  Temperature  Relative Humidity  Absolute Humidity
# 0          1268.0         13.6               48.9             0.7578
# 1           972.0         13.3               47.7             0.7255
# 2          1074.0         11.9               54.0             0.7502
# 3          1203.0         11.0               60.0             0.7867
# 4          1110.0         11.2               59.6             0.7888
# ...           ...          ...                ...                ...
# 9466          NaN          NaN                NaN                NaN
# 9467          NaN          NaN                NaN                NaN
# 9468          NaN          NaN                NaN                NaN
# 9469          NaN          NaN                NaN                NaN
# 9470          NaN          NaN                NaN                NaN
#
# [9471 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               9357 non-null   object
#  1   Time               9357 non-null   object
#  2   CO(GT)             9357 non-null   float64
#  3   PT08.S1(CO)        9357 non-null   float64
#  4   NMHC(GT)           9357 non-null   float64
#  5   C6H6(GT)           9357 non-null   float64
#  6   PT08.S2(NMHC)      9357 non-null   float64
#  7   NOx(GT)            9357 non-null   float64
#  8   PT08.S3(NOx)       9357 non-null   float64
#  9   NO2(GT)            9357 non-null   float64
#  10  PT08.S4(NO2)       9357 non-null   float64
#  11  PT08.S5(O3)        9357 non-null   float64
#  12  Temperature        9357 non-null   float64
#  13  Relative Humidity  9357 non-null   float64
#  14  Absolute Humidity  9357 non-null   float64
# dtypes: float64(13), object(2)
# memory usage: 1.1+ MB

# %%
df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#    Temperature  Relative Humidity  Absolute Humidity
# 0         13.6               48.9             0.7578
# 1         13.3               47.7             0.7255
# 2         11.9               54.0             0.7502
# 3         11.0               60.0             0.7867
# 4         11.2               59.6             0.7888

# %%
df=df.drop_duplicates()

# %%
df.isna().sum()
# Out:
# Date                 1
# Time                 1
# CO(GT)               1
# PT08.S1(CO)          1
# NMHC(GT)             1
# C6H6(GT)             1
# PT08.S2(NMHC)        1
# NOx(GT)              1
# PT08.S3(NOx)         1
# NO2(GT)              1
# PT08.S4(NO2)         1
# PT08.S5(O3)          1
# Temperature          1
# Relative Humidity    1
# Absolute Humidity    1
# dtype: int64

# %%
df = df.fillna(df.select_dtypes(include='number').mean())

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Date                 0
# Time                 0
# CO(GT)               0
# PT08.S1(CO)          0
# NMHC(GT)             0
# C6H6(GT)             0
# PT08.S2(NMHC)        0
# NOx(GT)              0
# PT08.S3(NOx)         0
# NO2(GT)              0
# PT08.S4(NO2)         0
# PT08.S5(O3)          0
# Temperature          0
# Relative Humidity    0
# Absolute Humidity    0
# dtype: int64

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)  Temperature  Relative Humidity  Absolute Humidity
# 0          1268.0         13.6               48.9             0.7578
# 1           972.0         13.3               47.7             0.7255
# 2          1074.0         11.9               54.0             0.7502
# 3          1203.0         11.0               60.0             0.7867
# 4          1110.0         11.2               59.6             0.7888
# ...           ...          ...                ...                ...
# 9352       1729.0         21.9               29.3             0.7568
# 9353       1269.0         24.3               23.7             0.7119
# 9354       1092.0         26.9               18.3             0.6406
# 9355        770.0         28.3               13.5             0.5139
# 9356        816.0         28.5               13.1             0.5028
#
# [9357 rows x 15 columns]

# %%
df['Absolute Humidity'] = df['Absolute Humidity'].multiply(100)

# %%
df
# Out:
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10.00.00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11.00.00     2.4       1163.0    -200.0      11.4
# 9354  04/04/2005  12.00.00     2.4       1142.0    -200.0      12.4
# 9355  04/04/2005  13.00.00     2.1       1003.0    -200.0       9.5
# 9356  04/04/2005  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)  Temperature  Relative Humidity  Absolute Humidity
# 0          1268.0         13.6               48.9             7578.0
# 1           972.0         13.3               47.7             7255.0
# 2          1074.0         11.9               54.0             7502.0
# 3          1203.0         11.0               60.0             7867.0
# 4          1110.0         11.2               59.6             7888.0
# ...           ...          ...                ...                ...
# 9352       1729.0         21.9               29.3             7568.0
# 9353       1269.0         24.3               23.7             7119.0
# 9354       1092.0         26.9               18.3             6406.0
# 9355        770.0         28.3               13.5             5139.0
# 9356        816.0         28.5               13.1             5028.0
#
# [9357 rows x 15 columns]

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
def remove_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75) 
    IQR = Q3 - Q1 
    threshold = 1.5 * IQR
    outlier_mask = (column < Q1 - threshold) | (column > Q3 + threshold)
    return column[~outlier_mask]

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'Temperature', 'Relative Humidity', 'Absolute Humidity'],
#       dtype='object')

# %%
# Remove outliers for each column using a loop

# %%
col_name = ['Temperature','Relative Humidity','Absolute Humidity','PT08.S4(NO2)','PT08.S5(O3)','C6H6(GT)', 'PT08.S2(NMHC)','PT08.S1(CO)']

# %%
for col in col_name: 
    df[col] = remove_outliers(df[col])

# %%
df['Year'] = pd.to_datetime(df['Date']).dt.year

# %%
df['Month'] = pd.to_datetime(df['Date']).dt.month

# %%
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0    2004-10-03  18.00.00     2.6       1360.0     150.0      11.9
# 1    2004-10-03  19.00.00     2.0       1292.0     112.0       9.4
# 2    2004-10-03  20.00.00     2.2       1402.0      88.0       9.0
# 3    2004-10-03  21.00.00     2.2       1376.0      80.0       9.2
# 4    2004-10-03  22.00.00     1.6       1272.0      51.0       6.5
# ...         ...       ...     ...          ...       ...       ...
# 9352 2005-04-04  10.00.00     3.1       1314.0    -200.0      13.5
# 9353 2005-04-04  11.00.00     2.4       1163.0    -200.0      11.4
# 9354 2005-04-04  12.00.00     2.4       1142.0    -200.0      12.4
# 9355 2005-04-04  13.00.00     2.1       1003.0    -200.0       9.5
# 9356 2005-04-04  14.00.00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)  Temperature  Relative Humidity  Absolute Humidity    Year  \
# 0          1268.0         13.6               48.9             7578.0  2004.0
# 1           972.0         13.3               47.7             7255.0  2004.0
# 2          1074.0         11.9               54.0             7502.0  2004.0
# 3          1203.0         11.0               60.0             7867.0  2004.0
# 4          1110.0         11.2               59.6             7888.0  2004.0
# ...           ...          ...                ...                ...     ...
# 9352       1729.0         21.9               29.3             7568.0  2005.0
# 9353       1269.0         24.3               23.7             7119.0  2005.0
# 9354       1092.0         26.9               18.3             6406.0  2005.0
# 9355        770.0         28.3               13.5             5139.0  2005.0
# 9356        816.0         28.5               13.1             5028.0  2005.0
#
#       Month
# 0      10.0
# 1      10.0
# 2      10.0
# 3      10.0
# 4      10.0
# ...     ...
# 9352    4.0
# 9353    4.0
# 9354    4.0
# 9355    4.0
# 9356    4.0
#
# [9357 rows x 17 columns]

# %%
df['Year'] = pd.to_datetime(df['Date']).dt.year

# %%
df['Month'] = pd.to_datetime(df['Date']).dt.month

# %%
df['yearr']= df.Year.astype(str)

# %%
df['month']= df.Month.astype(str)

# %%
#Plot correlation heatmap

# %%
plt.figure(figsize=(8, 6))

# %%
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
#       2 plt.title('Correlation Heatmap')
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
print(df.dtypes)
# Out:
# Date                 datetime64[ns]
# Time                         object
# CO(GT)                      float64
# PT08.S1(CO)                 float64
# NMHC(GT)                    float64
# C6H6(GT)                    float64
# PT08.S2(NMHC)               float64
# NOx(GT)                     float64
# PT08.S3(NOx)                float64
# NO2(GT)                     float64
# PT08.S4(NO2)                float64
# PT08.S5(O3)                 float64
# Temperature                 float64
# Relative Humidity           float64
# Absolute Humidity           float64
# Year                        float64
# Month                       float64
# yearr                        object
# month                        object
# dtype: object

# %%
df['yearr'] = pd.to_numeric(df['yearr'], errors='coerce')

# %%
df['month'] = pd.to_numeric(df['month'], errors='coerce')

# %%
df['Time'] = pd.to_numeric(df['Time'], errors='coerce')

# %%
df
# Out:
#            Date  Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# 0    2004-10-03   NaN     2.6       1360.0     150.0      11.9         1046.0
# 1    2004-10-03   NaN     2.0       1292.0     112.0       9.4          955.0
# 2    2004-10-03   NaN     2.2       1402.0      88.0       9.0          939.0
# 3    2004-10-03   NaN     2.2       1376.0      80.0       9.2          948.0
# 4    2004-10-03   NaN     1.6       1272.0      51.0       6.5          836.0
# ...         ...   ...     ...          ...       ...       ...            ...
# 9352 2005-04-04   NaN     3.1       1314.0    -200.0      13.5         1101.0
# 9353 2005-04-04   NaN     2.4       1163.0    -200.0      11.4         1027.0
# 9354 2005-04-04   NaN     2.4       1142.0    -200.0      12.4         1063.0
# 9355 2005-04-04   NaN     2.1       1003.0    -200.0       9.5          961.0
# 9356 2005-04-04   NaN     2.2       1071.0    -200.0      11.9         1047.0
#
#       NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  Temperature  \
# 0       166.0        1056.0    113.0        1692.0       1268.0         13.6
# 1       103.0        1174.0     92.0        1559.0        972.0         13.3
# 2       131.0        1140.0    114.0        1555.0       1074.0         11.9
# 3       172.0        1092.0    122.0        1584.0       1203.0         11.0
# 4       131.0        1205.0    116.0        1490.0       1110.0         11.2
# ...       ...           ...      ...           ...          ...          ...
# 9352    472.0         539.0    190.0        1374.0       1729.0         21.9
# 9353    353.0         604.0    179.0        1264.0       1269.0         24.3
# 9354    293.0         603.0    175.0        1241.0       1092.0         26.9
# 9355    235.0         702.0    156.0        1041.0        770.0         28.3
# 9356    265.0         654.0    168.0        1129.0        816.0         28.5
#
#       Relative Humidity  Absolute Humidity    Year  Month   yearr  month
# 0                  48.9             7578.0  2004.0   10.0  2004.0   10.0
# 1                  47.7             7255.0  2004.0   10.0  2004.0   10.0
# 2                  54.0             7502.0  2004.0   10.0  2004.0   10.0
# 3                  60.0             7867.0  2004.0   10.0  2004.0   10.0
# 4                  59.6             7888.0  2004.0   10.0  2004.0   10.0
# ...                 ...                ...     ...    ...     ...    ...
# 9352               29.3             7568.0  2005.0    4.0  2005.0    4.0
# 9353               23.7             7119.0  2005.0    4.0  2005.0    4.0
# 9354               18.3             6406.0  2005.0    4.0  2005.0    4.0
# 9355               13.5             5139.0  2005.0    4.0  2005.0    4.0
# 9356               13.1             5028.0  2005.0    4.0  2005.0    4.0
#
# [9357 rows x 19 columns]

# %%
print(df.dtypes)
# Out:
# Date                 datetime64[ns]
# Time                        float64
# CO(GT)                      float64
# PT08.S1(CO)                 float64
# NMHC(GT)                    float64
# C6H6(GT)                    float64
# PT08.S2(NMHC)               float64
# NOx(GT)                     float64
# PT08.S3(NOx)                float64
# NO2(GT)                     float64
# PT08.S4(NO2)                float64
# PT08.S5(O3)                 float64
# Temperature                 float64
# Relative Humidity           float64
# Absolute Humidity           float64
# Year                        float64
# Month                       float64
# yearr                       float64
# month                       float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'Temperature', 'Relative Humidity', 'Absolute Humidity',
#        'Year', 'Month', 'yearr', 'month'],
#       dtype='object')

# %%
#LinePlot

# %%
sns.lineplot(df,x="Year",y='Absolute Humidity')
# Out:
# <Axes: xlabel='Year', ylabel='Absolute Humidity'>

# %%
sns.lineplot(df,x="month",y='Absolute Humidity')
# Out:
# <Axes: xlabel='month', ylabel='Absolute Humidity'>

# %%
sns.lineplot(df,x="Year",y='Temperature')
# Out:
# <Axes: xlabel='Year', ylabel='Temperature'>

# %%
sns.lineplot(df,x="month",y='Temperature',)
# Out:
# <Axes: xlabel='month', ylabel='Temperature'>

# %%
sns.lineplot(df,x="month",y='CO(GT)',)
# Out:
# <Axes: xlabel='month', ylabel='CO(GT)'>

# %%
sns.lineplot(df,x="Year",y='NO2(GT)')
# Out:
# <Axes: xlabel='Year', ylabel='NO2(GT)'>

# %%
sns.lineplot(df,x="Year",y='Year')
# Out:
# <Axes: xlabel='Year', ylabel='Year'>

# %%
sns.lineplot(df,x='PT08.S1(CO)',y='PT08.S5(O3)',hue='Year')
# Out:
# <Axes: xlabel='PT08.S1(CO)', ylabel='PT08.S5(O3)'>

# %%
sns.lineplot(df,x='PT08.S1(CO)',y='PT08.S5(O3)',hue='month')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sns.lineplot(df,x='PT08.S1(CO)',y='PT08.S5(O3)',hue='month')
#
# NameError: name 'sns' is not defined

# %%
#Barplot

# %%
sns.barplot(df,x=df.Year,y=df.Temperature)
# Out:
# <Axes: xlabel='Year', ylabel='Temperature'>

# %%
sns.barplot(df,x=df.Year,y='Absolute Humidity')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.barplot(df,x=df.Year,y='Absolute Humidity')
#
# NameError: name 'sns' is not defined

# %%
sns.barplot(df,x=df.month,y=df['CO(GT)'])
# Out:
# <Axes: xlabel='month', ylabel='CO(GT)'>

# %%
#Scatter Plot

# %%
sns.scatterplot(df,x='PT08.S1(CO)',y='PT08.S5(O3)', hue='yearr')
# Out:
# <Axes: xlabel='PT08.S1(CO)', ylabel='PT08.S5(O3)'>

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO(GT)', 'PT08.S1(CO)', 'NMHC(GT)', 'C6H6(GT)',
#        'PT08.S2(NMHC)', 'NOx(GT)', 'PT08.S3(NOx)', 'NO2(GT)', 'PT08.S4(NO2)',
#        'PT08.S5(O3)', 'Temperature', 'Relative Humidity', 'Absolute Humidity',
#        'Year', 'Month', 'yearr', 'month'],
#       dtype='object')

# %%
sns.scatterplot(df,x='NO2(GT)',y='NOx(GT)', hue='month')
# Out:
# <Axes: xlabel='NO2(GT)', ylabel='NOx(GT)'>

# %%
sns.scatterplot(df,y='PT08.S2(NMHC)',x='PT08.S1(CO)', hue='yearr')
# Out:
# <Axes: xlabel='PT08.S1(CO)', ylabel='PT08.S2(NMHC)'>

# %%
sns.scatterplot(df,y='PT08.S2(NMHC)',x='PT08.S1(CO)', hue='month')
# Out:
# <Axes: xlabel='PT08.S1(CO)', ylabel='PT08.S2(NMHC)'>
